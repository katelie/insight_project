# %%
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; float:center}</style>")
# Out:
# <style>.container { width:100% !important; float:center}</style>

# %%
from __future__ import division, print_function

import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords

import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
from sklearn.cross_validation import KFold, StratifiedKFold, cross_val_score




# %matplotlib inline



sns.set_context('talk', font_scale=1.5)
sns.set_style('ticks', {'font.family': [u'sans-serif']})

punctuation = ['.',',',':','!',';','-','?','"',"'",'(',')','—']   
other = ['ive','ve', "i've", "i'v", 'i’ll', 'i’ve', 'i’v']  # 'deb','hideb','don','didn','twaittry','doesn','thank','heydeb',
mystops = stopwords.words('english') + punctuation + other

# %% [raw]
# def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
#     plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
#     plt.colorbar()
#     tick_marks = np.arange(len(comments_with_sentences_100_classified.category_simple.unique()))
#     plt.xticks(tick_marks, comments_with_sentences_100_classified.category_simple.unique(), rotation=45)
#     plt.yticks(tick_marks, comments_with_sentences_100_classified.category_simple.unique())
#     plt.tight_layout()
#     plt.ylabel('True label')
#     plt.xlabel('Predicted label')

# %% [markdown]
# import & sanity check

# %%
comments_with_sentences_100_classified = pd.read_csv('comments_with_sentences_100_classified_4classes.csv',index_col=0)
# comments_with_sentences_100_classified = comments_with_sentences_100_classified.dropna(how='any')

# %%
comments_with_sentences_100_classified = comments_with_sentences_100_classified.dropna()

# %%
comments_with_sentences_100_classified['category_simple'] = comments_with_sentences_100_classified.category
comments_with_sentences_100_classified['category_simple'] = comments_with_sentences_100_classified.category_simple.replace(['addition','substitution','omission'],'helpful')

# %%
comments_with_sentences_100_classified.category_simple.unique()
# Out:
# array(['other', 'helpful'], dtype=object)

# %%
comments_with_sentences_100_classified.shape
# Out:
# (94611, 20)

# %% [raw]
# comments_with_sentences_100_classified = comments_with_sentences_100_classified.loc[pd.notnull(comments_with_sentences_100_classified['category']),:]

# %% [raw]
# comments_with_sentences_100_classified[comments_with_sentences_100_classified.category_simple == 'other']

# %% [raw]
# comments_with_sentences_100_classified.loc[97286, 'usercomment']

# %%
comments_with_sentences_100_classified.to_csv('training_data.csv')

# %% [markdown]
# # pipeline - identify 'helpful' vs 'other' comments

# %% [markdown]
# ### define data sets

# %%
X = comments_with_sentences_100_classified.sentence_tokens_stemmed
Y = comments_with_sentences_100_classified.category_simple

# %%
num_folds = 10
num_instances = len(X)
seed = 42

kfold = KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %%
split = 20000
X_train = comments_with_sentences_100_classified.sentence_tokens_stemmed[:split] #\.as_matrix()
target_train = comments_with_sentences_100_classified.category_simple[:split] #.as_matrix()
target_train.replace(['addition','substitution','omission'],'helpful',inplace=True)


X_test = comments_with_sentences_100_classified.sentence_tokens_stemmed[split:]
target_test = comments_with_sentences_100_classified.category_simple[split:]
target_test.replace(['addition','substitution','omission'],'helpful',inplace=True)

test_all = comments_with_sentences_100_classified[split:]

# encode classes labels as ints
target_test_bin = LabelEncoder().fit_transform(target_test)
# list(labelencoder.classes_)

len(X_test), len(target_test)
# Out:
# (74611, 74611)

# %%
{print('total comments that should be helpful, %i' % test_all[test_all.category_simple == 'helpful'].category.count())}
{print('total comments that should be other, %i' % test_all[test_all.category_simple == 'other'].category.count())}
# Out:
# total comments that should be helpful, 5192
# total comments that should be other, 69419
# {None}

# %% [markdown]
# ## Naive Bayes classifier

# %%
classifier_helpful_NB = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=1000000, min_df=3)),
                                  ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
                                  ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

classifier_helpful_NB.fit(X_train, target_train) 
predicted_NB = classifier_helpful_NB.predict(X_test) 
confmatrix_NB = confusion_matrix(target_test, predicted_NB)
probs_NB = classifier_helpful_NB.predict_proba(X_test)

predicted_NB_bin = LabelEncoder().fit_transform(predicted_NB)
falsepos_NB, truepos_NB, _ = sklearn.metrics.roc_curve(target_test_bin, probs_NB[:,1]) # 2nd column is positive class


print('accuracy, %0.4f' % np.mean(predicted_NB == target_test))
print('score, %0.4f' % classifier_helpful_NB.score(X_test,target_test))
print('confusion matrix', confmatrix_NB)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_NB) & (test_all.category_simple == 'helpful' )].shape[0])
print('prob/recall/F1', precision_recall_fscore_support(target_test_bin, predicted_NB_bin))
# Out:
# accuracy, 0.9377
# score, 0.9377
# confusion matrix [[  573  4619]
#  [   31 69388]]
# correctly classified helpful 573
# prob/recall/F1 (array([ 0.9486755 ,  0.93758699]), array([ 0.1103621 ,  0.99955344]), array([ 0.19772257,  0.9675791 ]), array([ 5192, 69419]))

# %%
results_NB = cross_val_score(classifier_helpful_NB, X, Y, cv=kfold)
print(results_NB.mean())
# Out:
# 0.947321155628

# %% [markdown]
# ## stochastic gradient descent classifier (logarithmic)

# %%
classifier_helpful_SGD = Pipeline([('vectorizer', CountVectorizer(ngram_range=(1,6), stop_words=mystops, max_df=100000, min_df=2)),
                                   ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
                                   ('classifier', SGDClassifier(alpha=0.0005, average=False, class_weight={'helpful':8.5, 'other':0.7}, epsilon=0.1,
                                eta0=0, fit_intercept=True, l1_ratio=0, learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
                                penalty='l2', power_t=0.5, random_state=42, shuffle=True))])

classifier_helpful_SGD = classifier_helpful_SGD.fit(X_train, target_train)
predicted_SGD = classifier_helpful_SGD.predict(X_test)
confmatrix_SGD = confusion_matrix(target_test, predicted_SGD)
probs_SGD = classifier_helpful_SGD.predict_proba(X_test)

predicted_SGD_bin = LabelEncoder().fit_transform(predicted_SGD)
falsepos_SGD, truepos_SGD, _ = sklearn.metrics.roc_curve(target_test_bin, probs_SGD[:,1]) # 2nd column is positive class


print('accuracy, %0.4f' % np.mean(predicted_SGD == target_test))
print('score, %0.4f' % classifier_helpful_SGD.score(X_test,target_test))
print('confusion matrix', confmatrix_SGD)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_SGD) & (test_all.category_simple == 'helpful' )].shape[0])
# print('prob/recall/F1', precision_recall_fscore_support(target_test_bin, predicted_SGD_bin))
print(precision_recall_fscore_support(target_test_bin, predicted_SGD_bin))

lw = 3
fig, ax = plt.subplots(figsize=(6,5))
ax.plot([0,1],[0,1],'k--')
ax.plot(falsepos_NB, truepos_NB, 'b', label='Naïve Bayes', linewidth=lw)
ax.plot(falsepos_SGD, truepos_SGD, 'r', label='logistic reg (SGD)', linewidth=lw)

ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
ax.set_title('ROC curve')
ax.legend(loc='best')
sns.despine()

# plt.savefig('ROC_curve.jpg')
# Out:
# accuracy, 0.9331
# score, 0.9331
# confusion matrix [[ 4408   784]
#  [ 4205 65214]]
# correctly classified helpful 4408
# (array([ 0.51178451,  0.98812085]), array([ 0.84899846,  0.93942581]), array([ 0.6386092 ,  0.96315824]), array([ 5192, 69419]))

# %%
X_test[predicted_SGD=='helpful']
# Out:
# (7104,)

# %%
results_SGD = cross_val_score(classifier_helpful_SGD, X, Y, cv=kfold)
print(results_SGD.mean())
# Out:
# 0.950661131724

# %%
lw = 3
fig, ax = plt.subplots(figsize=(6,5))
ax.plot([0,1],[0,1],'k--')
ax.plot(falsepos_NB, truepos_NB, 'b', label='Naïve Bayes', linewidth=lw)
ax.plot(falsepos_SGD, truepos_SGD, 'r', label='SGD', linewidth=lw)


ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
ax.set_title('ROC curve')
ax.legend(loc='best')
sns.despine()

plt.savefig('ROC_curve.jpg')

# %% [markdown]
# ### with tf-idf

# %%
classifier_helpful_NB_tf = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=1000000, min_df=3)),
                     ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=False)),
                     ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

classifier_helpful_NB_tf.fit(X_train, target_train) 
predicted_NB_tf = classifier_helpful_NB.predict(X_test) 
confmatrix_NB_tf = confusion_matrix(target_test, predicted_NB_tf)

probs_NB_tf = classifier_helpful_NB_tf.predict_proba(X_test)
falsepos_NB_tf, truepos_NB_tf, _ = sklearn.metrics.roc_curve(target_test_bin, probs_NB_tf[:,1])



print('accuracy, %0.4f' % np.mean(predicted_NB_tf == target_test))
print('score, %0.4f' % classifier_helpful_NB_tf.score(X_test,target_test))
print('confusion matrix', confmatrix_NB_tf)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_NB_tf) & (test_all.category_simple == 'helpful' )].shape[0])



classifier_helpful_SGD_tf = Pipeline([('vectorizer', CountVectorizer(ngram_range=(1,6), stop_words=mystops, max_df=100000, min_df=2)),
                     ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=False)),
                     ('classifier', SGDClassifier(alpha=0.0005, average=False, class_weight={'helpful':8.25, 'other':0.75}, epsilon=0.1,
                                eta0=0, fit_intercept=True, l1_ratio=0, learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
                                penalty='l2', power_t=0.5, random_state=42, shuffle=True))])

classifier_helpful_SGD_tf = classifier_helpful_SGD_tf.fit(X_train, target_train)
predicted_SGD_tf = classifier_helpful_SGD_tf.predict(X_test)
confmatrix_SGD_tf = confusion_matrix(target_test, predicted_SGD_tf)

probs_SGD_tf = classifier_helpful_SGD_tf.predict_proba(X_test)
falsepos_SGD_tf, truepos_SGD_tf, _ = sklearn.metrics.roc_curve(target_test_bin, probs_SGD_tf[:,1])


print('accuracy, %0.4f' % np.mean(predicted_SGD_tf == target_test))
print('score, %0.4f' % classifier_helpful_SGD_tf.score(X_test,target_test))
print('confusion matrix', confmatrix_SGD_tf)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_SGD_tf) & (test_all.category_simple == 'helpful' )].shape[0])


classifier_helpful_NB_tfidf = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=1000000, min_df=3)),
                     ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
                     ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

classifier_helpful_NB_tfidf.fit(X_train, target_train) 
predicted_NB_tfidf = classifier_helpful_NB.predict(X_test) 
confmatrix_NB_tfidf = confusion_matrix(target_test, predicted_NB_tfidf)

probs_NBtf_idf = classifier_helpful_NBtf_idf.predict_proba(X_test)
falsepos_NB_tfidf, truepos_NB_tfidf, _ = sklearn.metrics.roc_curve(target_test_bin, probs_NB_tfidf[:,1])


print('accuracy, %0.4f' % np.mean(predicted_NB_tfidf == target_test))
print('score, %0.4f' % classifier_helpful_NB_tfidf.score(X_test,target_test))
print('confusion matrix', confmatrix_NB_tfidf)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_NB_tfidf) & (test_all.category_simple == 'helpful' )].shape[0])



classifier_helpful_SGD_tfidf = Pipeline([('vectorizer', CountVectorizer(ngram_range=(1,6), stop_words=mystops, max_df=100000, min_df=2)),
                     ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
                     ('classifier', SGDClassifier(alpha=0.0005, average=False, class_weight={'helpful':8.25, 'other':0.75}, epsilon=0.1,
                                eta0=0, fit_intercept=True, l1_ratio=0, learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
                                penalty='l2', power_t=0.5, random_state=42, shuffle=True))])

classifier_helpful_SGD_tfidf = classifier_helpful_SGD_tfidf.fit(X_train, target_train)
predicted_SGD_tfidf = classifier_helpful_SGD_tfidf.predict(X_test)
confmatrix_SGD_tfidf = confusion_matrix(target_test, predicted_SGD_tfidf)

probs_SGD_tfidf = classifier_helpful_SGD_tf_idf.redict_proba(X_test)
falsepos_SGD_tfidf, truepos_SGD_tfidf, _ = sklearn.metrics.roc_curve(target_test_bin, probs_SGD_tfidf[:,1])


print('accuracy, %0.4f' % np.mean(predicted_SGD_tfidf == target_test))
print('score, %0.4f' % classifier_helpful_SGD_tfidf.score(X_test,target_test))
print('confusion matrix', confmatrix_SGD_tfidf)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_SGD_tfidf) & (test_all.category_simple == 'helpful' )].shape[0])




lw = 3
fig, ax = plt.subplots(figsize=(6,5))
ax.plot([0,1],[0,1],'k--')
ax.plot(falsepos_NB, truepos_NB, 'b', label='Naive Bayes', linewidth=lw)
ax.plot(falsepos_SGD, truepos_SGD, 'r', label='SGD', linewidth=lw)

ax.plot(falsepos_NB_tfidf, truepos_NB_tf, 'g', label='Naive Bayes + tf', linewidth=lw)
ax.plot(falsepos_SGD_tfidf, truepos_SGD_tf, 'y', label='SGD + tf', linewidth=lw)

ax.plot(falsepos_NB_tfidf, truepos_NB_tfidf, 'c--', label='Naive Bayes + tf-idf', linewidth=lw)
ax.plot(falsepos_SGD_tfidf, truepos_SGD_tfidf, 'm--', label='SGD + tf-idf', linewidth=lw)



ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
ax.set_title('ROC curve')
ax.legend(loc='best')
sns.despine()

plt.savefig('ROC_curve_tfidf.jpg')
# Out:
# accuracy, 0.9420
# score, 0.9388
# confusion matrix [[ 1286  3906]
#  [  421 68998]]
# correctly classified helpful 1286
# accuracy, 0.9266
# score, 0.9266
# confusion matrix [[ 4247   945]
#  [ 4529 64890]]
# correctly classified helpful 4247
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4507ae953e26> in <module>()
#      47 confmatrix_NB_tfidf = confusion_matrix(target_test, predicted_NB_tfidf)
#      48
# ---> 49 probs_NBtf_idf = classifier_helpful_NBtf_idf.predict_proba(X_test)
#      50 falsepos_NB_tfidf, truepos_NB_tfidf, _ = sklearn.metrics.roc_curve(target_test_bin, probs_NB_tfidf[:,1])
#      51
#
# NameError: name 'classifier_helpful_NBtf_idf' is not defined

# %% [markdown]
# # pipeline - identify 'substitute' vs 'add/omit' versus comments

# %%
helpful_comments.columns
# Out:
# Index(['sentence', 'commentID', 'child_id', 'children', 'comment_time',
#        'recipenumber', 'title', 'url', 'usercomment', 'username', 'usersite',
#        'usercomment_lower', 'tokens', 'tokens_stemmed', 'sentence_tokens',
#        'sentence_tokens_stemmed', 'sentiment_polarity_comment',
#        'sentiment_polarity_sentence', 'category', 'category_simple'],
#       dtype='object')

# %%
X2 = comments_with_sentences_100_classified.loc[comments_with_sentences_100_classified.category_simple == 'helpful', 'sentence_tokens_stemmed']
Y2 = comments_with_sentences_100_classified.loc[comments_with_sentences_100_classified.category_simple == 'helpful', 'category']

target_test_bin = LabelEncoder().fit_transform(target_test)

# %%
num_folds = 10
num_instances = len(X2)
seed = 42

kfold = KFold(n=num_instances, n_folds=num_folds, random_state=seed)

# %%
results_SGD = cross_val_score(classifier_helpful_SGD, X2, Y2, cv=kfold)
print(results_SGD.mean())

# %% [markdown]
# ### define data sets

# %%
helpful_comments = comments_with_sentences_100_classified.loc[comments_with_sentences_100_classified.category_simple == 'helpful', :]
helpful_comments.shape
# Out:
# (6627, 20)

# %%
helpful_comments.category.unique()
# Out:
# array(['substitution', 'omission', 'addition'], dtype=object)

# %%
split = 2000
X_train = helpful_comments.sentence_tokens_stemmed[:split] #\.as_matrix()
target_train = helpful_comments.category[:split] #.as_matrix()
target_train.replace(['addition','omission'],'add_subtract',inplace=True)
target_train = LabelEncoder().fit_transform(target_train)

X_test = helpful_comments.sentence_tokens_stemmed[split:]
target_test = helpful_comments.category[split:]
target_test.replace(['addition','omission'],'add_subtract',inplace=True)

test_all = helpful_comments[split:]

# encode classes labels as ints
target_test_bin = LabelEncoder().fit_transform(target_test)
# list(labelencoder.classes_)

len(X_test), len(target_test)
# Out:
# (4627, 4627)

# %% [markdown]
# ## Naive Bayes classifier

# %%
print('total comments that should be helpful, %i;    total comments that should be other, %i' % 
      (test_all[test_all.category == 'substitution'].category.count(), test_all[test_all.category == 'add_subtract'].category.count()))
# Out:
# total comments that should be helpful, 3502;    total comments that should be other, 1125

# %%
classifier_helpful_NB = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=1000000, min_df=3)),
                     ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

classifier_helpful_NB.fit(X_train, target_train) 
predicted_NB = classifier_helpful_NB.predict(X_test) 
confmatrix_NB = confusion_matrix(target_test, predicted_NB)

predicted_NB_bin = LabelEncoder().fit_transform(predicted_NB)
falsepos_NB, truepos_NB, _ = sklearn.metrics.roc_curve(target_test_bin, predicted_NB_bin)


print('accuracy, %0.4f' % np.mean(predicted_NB == target_test))
print('score, %0.4f' % classifier_helpful_NB.score(X_test,target_test))
print('confusion matrix', confmatrix_NB)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_NB) & (test_all.category_simple == 'helpful' )].shape[0])
# Out:
# accuracy, 0.8489
# score, 0.8489
# confusion matrix [[ 533  592]
#  [ 107 3395]]
# correctly classified helpful 0

# %% [markdown]
# ## stochastic gradient descent classifier (made logarithmic)

# %%
classifier_helpful_SGD = Pipeline([('vectorizer', CountVectorizer(ngram_range=(1,6), stop_words=mystops, max_df=100000, min_df=2)),
                     ('classifier', SGDClassifier(alpha=0.0005, average=False, class_weight={'helpful':8.25, 'other':0.75}, epsilon=0.1,
                                eta0=0, fit_intercept=True, l1_ratio=0, learning_rate='optimal', loss='log', n_iter=50, n_jobs=1,
                                penalty='l2', power_t=0.5, random_state=42, shuffle=True))])

classifier_helpful_SGD = classifier_helpful_SGD.fit(X_train, target_train)
predicted_SGD = classifier_helpful_SGD.predict(X_test)
confmatrix_SGD = confusion_matrix(target_test, predicted_SGD)

predicted_SGD_bin = LabelEncoder().fit_transform(predicted_SGD)
falsepos_SGD, truepos_SGD, _ = sklearn.metrics.roc_curve(target_test_bin, predicted_SGD_bin)


print('accuracy, %0.4f' % np.mean(predicted_SGD == target_test))
print('score, %0.4f' % classifier_helpful_SGD.score(X_test,target_test))
print('confusion matrix', confmatrix_SGD)
print('correctly classified helpful %i' % test_all[(test_all.category_simple == predicted_SGD) & (test_all.category_simple == 'helpful' )].shape[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-409-a7b9b84fd87b> in <module>()
#       4                                 penalty='l2', power_t=0.5, random_state=42, shuffle=True))])
#       5
# ----> 6 classifier_helpful_SGD = classifier_helpful_SGD.fit(X_train, target_train)
#       7 predicted_SGD = classifier_helpful_SGD.predict(X_test)
#       8 confmatrix_SGD = confusion_matrix(target_test, predicted_SGD)
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     163         """
#     164         Xt, fit_params = self._pre_transform(X, y, **fit_params)
# --> 165         self.steps[-1][-1].fit(Xt, y, **fit_params)
#     166         return self
#     167
#
# ...

# %%
lw = 3
fig, ax = plt.subplots(figsize=(6,5))
ax.plot([0,1],[0,1],'k--')
ax.plot(falsepos_NB, truepos_NB, 'b', label='Naive Bayes', linewidth=lw)
ax.plot(falsepos_SGD, truepos_SGD, 'r', label='SGD', linewidth=lw)


ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
ax.set_title('ROC curve')
ax.legend(loc='best')
sns.despine()

plt.savefig('ROC_curve.jpg')

# %% [raw]
# classifier_helpful = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=1000000, min_df=5)),
#                      ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=False)),
#                      ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])
#
# classifier_helpful.fit(X_train.as_matrix(), target_train.as_matrix())
# predicted = classifier_helpful.predict(X_test.as_matrix())
# np.mean(predicted == target_test), test_all[(test_all.category_simple == predicted) & (test_all.category_simple == 'helpful' )].shape[0]

# %% [raw]
# classifier0 = Pipeline([('vectorizer', CountVectorizer(ngram_range=(3,6), stop_words=mystops, max_df=1.0, min_df=0)),
#                      ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#                      ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])
#
# classifier0 = classifier0.fit(X_train, target_train)
#
# predicted = classifier0.predict(X_test)
#
# np.mean(predicted == target_test)

# %% [raw]
# classifier1 = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=100, min_df=2)),
#                      ('classifier', SGDClassifier())])
#
# classifier1 = classifier1.fit(X_train, target_train)
# predicted = classifier1.predict(X_test)
# np.mean(predicted == target_test), test_all[(test_all.category_simple == predicted) & (test_all.category_simple == 'helpful')].shape[0]

# %% [raw]
# classifier1 = Pipeline([('vectorizer', CountVectorizer(ngram_range=(2,6), stop_words=mystops, max_df=100000, min_df=5)),
#                      ('transformer', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=False)),
#                      ('classifier', SGDClassifier())])
#
# classifier1 = classifier1.fit(X_train, target_train)
#
# predicted = classifier1.predict(X_test)
#
#
# np.mean(predicted == target_test), test_all[(test_all.category_simple == predicted) & (test_all.category_simple == 'helpful' )].shape[0]

# %% [markdown]
# ### check it out and make sure things seem right

# %%
comments_with_sentences_100_classified[comments_with_sentences_100_classified.category_simple == 'helpful'].category.count() / comments_with_sentences_100_classified[comments_with_sentences_100_classified.category_simple != 'helpful'].category.count()
# Out:
# 0.075320512820512817

# %%
test_all[(test_all.category_simple == predicted) & (test_all.category_simple == 'helpful')].shape[0]/comments_with_sentences_100_classified[comments_with_sentences_100_classified.category_simple == 'helpful'].category.count()
# Out:
# 0.38177154066696845

# %%
a = test_all[(test_all.category_simple == predicted) & (test_all.category_simple == 'helpful' )]
a.shape
# Out:
# (1222, 20)

# %%
a #.loc[52935,'sentence']
# Out:
#                                                 sentence commentID child_id  \
# 51642  i have been reading your blog for a lot longer...     14887        0
# 51765  you’ve shown me ways to spice up old recipes i...     14919        0
# 52148  if using glass, you might benefit from reducin...     15031        0
# 52156  was there not enough room for the bread to coo...     15033      900
# 52157  i use a one-pound loaf of standard white sandw...     15034        0
# 52397  i’m not sure how i feel about the ricotta thou...     15107        0
# 52464        it makes them a bit easier to chew as well.     15134        0
# 52467  the cake still turned out pretty good, but nex...     15135       65
# 52518  i was wondering if this recipe could be conver...     15149        0
# 52576  deb, does anyone have a reason for not using c...     15168        0
# 52638  i reduced the amount of baking powder by one t...     15188        0
# ...

# %% [raw]
# predict_helpful = test_all.iloc[predicted == 'helpful']

# %% [raw]
# predicted == 'helpful'

# %% [raw]
# predict_helpful

# %%
X2
# Out:
#                                                 sentence commentID child_id  \
# 66     i’ve tried this version, and ended up returnin...        21        0
# 74     do you think bourban a decent replacement for ...        22        0
# 119    i use this for filled pies also to ensure a ni...        39        0
# 131    i agree with you about lemon and here’s a sugg...        42        0
# 162    i use it as substitute for cream or half/half ...        51        0
# 182    the “bean” instead of “beat” is still there, j...        60        0
# 185    mmm i’ve only stuck with pumpkin pie to date…t...        62        0
# 253    i wonder if any of my thanksgiving guests woul...        85        0
# 275    wonderful sweet potato filling in place of tha...        90        0
# 276                 gabriela what’s with this “instead”?        91        0
# 280    i’ve never had the nerve to make it (not entir...        92        0
# ...

# %%
X2 = comments_with_sentences_100_classified.loc[comments_with_sentences_100_classified.category_simple == 'helpful', :].reset_index()
Y2 = comments_with_sentences_100_classified.loc[comments_with_sentences_100_classified.category_simple == 'helpful', :]

# %%
X2[X2.title=='best cocoa brownies'].sentence.count(), comments_with_sentences_100_classified[comments_with_sentences_100_classified.title=='best cocoa brownies'].sentence.count()
# Out:
# (305, 3439)

# %%
predicted_SGD = classifier_helpful_SGD.predict(comments_with_sentences_100_classified[comments_with_sentences_100_classified.title == 'best cocoa brownies'].sentence_tokens_stemmed)

# %%
comments_with_sentences_100_classified.iloc[predicted_SGD == 'helpful'].sentence
# Out:
# 2                        ive never made sweet potato pie!
# 6       i was just thinking this morning that i would ...
# 14                          i can’t wait to try this one.
# 18      sometimes embedded, sometimes linked to an off...
# 20      i have just become aware of your blog, and thi...
# 24      plus, anything with buttermilk really makes me...
# 44                 anyway, looks delicious as always deb!
# 47                                thanks for this recipe.
# 63      i have been trying to figure out what to do w/...
# 65                               i love sweet potato pie!
# 66      i’ve tried this version, and ended up returnin...
# 67                            i love the tanginess of it!
# 78      i’d love to make this but the sweet potatoes w...
# 84                                                   yes.
# 86                                                   yes.
# 103     with recipes like this i’m tempted to off to c...
# ...
