# %%
from IPython.core.display import HTML
HTML("<style>.container { width:95% !important; float:center}</style>")
# Out:
# <style>.container { width:95% !important; float:center}</style>

# %%
from __future__ import division, print_function

import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
import textblob as tb
from textblob import TextBlob


from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer



# %matplotlib inline

sns.set_context('notebook', font_scale=1.5)
sns.set_style('ticks')

punctuation = ['.',',',':','!',';','-','?','"',"'",'(',')','—']   
other = ['ive','ve', "i've", "i'v", 'i’ll', 'i’ve', 'i’v']  # 'deb','hideb','don','didn','twaittry','doesn','thank','heydeb',
mystops = stopwords.words('english') + punctuation + other

# %%
comments_classified = pd.read_csv('comments_classified_SK_filtered2000_additional.csv',index_col=0)

comments_with_sentences_100 = pd.read_csv('comments_with_sentences_100.csv',index_col=0)
comments_only_100 = pd.read_csv('comments_only_100.csv',index_col=0)

comments_with_sentences_all = pd.read_csv('comments_with_sentences_all.csv',index_col=0)
comments_only_all = pd.read_csv('comments_only_all.csv',index_col=0)

# %%
recipes = pd.read_csv('/Users/kateliea/Documents/Insight/project/webscrapers/recipes_smittenkitchen_100.csv', index_col=0)

# %%
comments_with_sentences_100.columns
# Out:
# Index(['sentence', 'commentID', 'child_id', 'children', 'comment_time',
#        'recipenumber', 'title', 'url', 'usercomment', 'username', 'usersite',
#        'usercomment_lower', 'tokens', 'tokens_stemmed', 'sentence_tokens',
#        'sentence_tokens_stemmed', 'sentiment_polarity_comment',
#        'sentiment_polarity_sentence'],
#       dtype='object')

# %%
recipes['recipe_ID'] = recipes.index

recipes['recipe_ID'] = recipes['recipe_ID'].apply(lambda x: 'R'+str(x))

# %%
recipes.introductory_text
# Out:
# 'As many of you have figured out, I’ve got a megawatt crush on Southern food. It comes out with a vengeance all summer when I want nothing more than to dry-rub ribs, make corn bread and buttermilk dressing salads, dive headfirst into tomato pie and douse pretty much everything in bourbon then usually goes into a soft hibernation over the winter save a fried chicken or chicken and dumplings run-in or two.Given this infatuation, it seems only right and proper that I’d get in a recipe for sweet potato pie at a time of year when sweet potatoes are exactly everywhere. But while I do love me some sweet potato pie, there’s a heaviness about it that is exactly what some people like about it but leaves me feeling kind of lukewarm. So you can imagine when I spied this fluffier, tangier and [here’s the part I think you’re really going to remember] almost cheesecake-like version of it a cookbook written by and I’d like to believe for Manhattanites with a thing for Southern home cooking, I bookmarked it instantaneously and then sat on my hands/tapped my feet impatiently until sweet potato season came around.[Can you tell I went a little overboard with the sweet potatoes at the market? I have so many, I’m even tepidly considering cooking, pureeing and freezing some for that seemingly far-off time a few months from now sobpleasestopgrowingsofast when this fist-eater theoretically moves on to more nutritional solids.]This recipe is a total win, especially if you were looking for a brighter, lighter alternative to a traditional sweet potato pie. Just be sure to warn folks because it may look like tradition but it tastes like “surprise!” and you know, not everyone likes to be surprised when they cut into their Thanksgiving dessert. Which, frankly, just means more for you.Extra buttermilk to use up? I’ve got more buttermilk uses than you might know what to do with. Ice cream, anyone?'

# %%
comments_classified.columns
# Out:
# Index(['category', 'sentence', 'commentID', 'child_id', 'children',
#        'comment_time', 'recipenumber', 'title', 'url', 'usercomment',
#        'username', 'usersite', 'usercomment_lower', 'tokens', 'tokens_stemmed',
#        'sentence_bigrams', 'sentence_trigrams', 'sentence_tokens',
#        'sentence_tokens_stemmed', 'category_label'],
#       dtype='object')

# %%
def comment_sentiment(comment): 
    comment = tb.TextBlob(comment)
    return comment.sentiment.polarity

# %% [markdown]
# exploratory analysis of TextBlob

# %%
comments_classified.title[4]
# Out:
# 'sweet potato buttermilk\xa0pie'

# %%
txt = tb.TextBlob(comments_classified.usercomment[4])
txt
# Out:
# TextBlob("This is definitely going on my Must Make list. Here in North Carolina, sweet potatoes are in season year-round so I am always looking for new ways to eat them!")

# %%
txt.tags, txt.noun_phrases
# Out:
# ([('Ive', 'NNP'),
#   ('never', 'RB'),
#   ('made', 'VBD'),
#   ('sweet', 'JJ'),
#   ('potato', 'JJ'),
#   ('pie', 'NN'),
#   ('I’d', 'NNP'),
#   ('love', 'NN'),
#   ('to', 'TO'),
#   ('try', 'VB'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('Holidays', 'NNP')],
#  WordList(['ive', 'sweet potato pie', 'i’d', 'holidays']))

# %% [markdown]
# Sentiment(polarity, subjectivity). The polarity score is a float within the range [-1.0, 1.0]. The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.m

# %%
txt.sentiment
# Out:
# Sentiment(polarity=0.17348484848484846, subjectivity=0.5348484848484848)

# %%
comments_with_sentences_100['sentiment_polarity_sentence'] = comments_with_sentences_100.sentence.apply(comment_sentiment)

# %%
comments_with_sentences_100[(comments_with_sentences_100.sentiment_polarity_sentence > 0) & (comments_with_sentences_100.title=='best cocoa brownies')].sentiment_polarity_sentence.mean()
# Out:
# 0.4595538414182737

# %%
comment
# Out:
# TextBlob("This is definitely going on my Must Make list. Here in North Carolina, sweet potatoes are in season year-round so I am always looking for new ways to eat them!")

# %% [raw]
# x = range(7)
# negative_data = [-1,-4,-3,-2,-6,-2,-8]
# positive_data = [4,2,3,1,4,6,7,]
#
# fig = plt.figure()
# ax = plt.subplot(111)
# ax.bar(x, negative_data, width=1, color='r')
# ax.bar(x, positive_data, width=1, color='b')

# %%
title = recipes.title[2]

positive = 100*comments_with_sentences_100[
    (comments_with_sentences_100.sentiment_polarity_sentence > 0) 
    & (comments_with_sentences_100.title==title)].sentiment_polarity_sentence.mean()
negative = 100*comments_with_sentences_100[
    (comments_with_sentences_100.sentiment_polarity_sentence < 0) 
    & (comments_with_sentences_100.title==title)].sentiment_polarity_sentence.mean()

# %%
recipes.loc[recipes.title==title, 'numberofcomments']
# Out:
# 2    47
# Name: numberofcomments, dtype: int64

# %%
(positive - negative)*(recipes[recipes.title==title].numberofcomments)
# Out:
# 2    3506.751321
# Name: numberofcomments, dtype: float64

# %% [raw]
# positive = 100*comments_with_sentences_100[
#     (comments_with_sentences_100.sentiment_polarity_sentence > 0)
#     & (comments_with_sentences_100.title=='best cocoa brownies')].sentiment_polarity_sentence.mean()
# negative = 100*comments_with_sentences_100[
#     (comments_with_sentences_100.sentiment_polarity_sentence < 0)
#     & (comments_with_sentences_100.title=='best cocoa brownies')].sentiment_polarity_sentence.mean()
#
#
# width = 0.2
# lw=0
#
# with sns.axes_style({'font.family': [u'sans-serif']}):
#     sns.set_context('notebook', font_scale=1.5)
#     fig, ax = plt.subplots(figsize=(5,1))
#     ax.barh(0, positive, color='orange', linewidth=lw)
#     ax.barh(0, negative, color='blue', linewidth=lw)
#
#     ax.set_xlim((-60,60))
#     ax.set_yticks(ticks=[])
#     ax.set_title('recipe happiness')
#     sns.despine(offset=20, trim=True, left=True)

# %%
def happiness_graph(recipe):
    width = 0.2
    lw=0
    fig, ax = plt.subplots(figsize=(5,1))
    
    with sns.axes_style({'font.family': [u'sans-serif']}):
        sns.set_context('notebook', font_scale=1.5)
        ax.barh(0, positive, color='orange', linewidth=lw)
        ax.barh(0, negative, color='blue', linewidth=lw)

        ax.set_xlim((-60,60))
        ax.set_yticks(ticks=[])
        ax.set_title('recipe happiness (%)')
        sns.despine(offset=20, trim=True, left=True)
        
    plt.savefig('/Users/kateliea/Documents/Insight/project/images/' + name + '.jpg')

# %%
recipes.columns
# Out:
# Index(['article_id', 'author', 'author_url', 'directions', 'firstimageURL',
#        'ingredients', 'introductory_text', 'numberofcomments', 'published',
#        'recipe_notes', 'servings', 'time', 'title', 'updated', 'url',
#        'recipe_ID'],
#       dtype='object')

# %% [markdown]
# create a data table with the recipe sentiment, ranked by happiness score
#
# include name for happiness plot

# %%
# recipe_ranks = pd.DataFrame()
reicpe_ranks = {}

for i, recipe_title in enumerate(comments_with_sentences_100.title.unique()):
        recipe_sentiment = {}
        
        recipe_sentiment['recipe_title'] = recipe_title

        recipe_sentiment['recipe_ID'] = recipes[recipes.title == recipe_title].recipe_ID
        
        recipe_sentiment['numberofcomments'] = recipes[recipes.title == recipe_title].numberofcomments
        
        recipe_sentiment['mean_positivity_sentences'] = 100*comments_with_sentences_100[
                    (comments_with_sentences_100.sentiment_polarity_sentence > 0) 
                    & (comments_with_sentences_100.title == recipe_title)].sentiment_polarity_sentence.mean()
        
        recipe_sentiment['mean_positivity_comment'] = 100*comments_with_sentences_100[
                    (comments_with_sentences_100.sentiment_polarity_comment > 0) 
                    & (comments_with_sentences_100.title == recipe_title)].sentiment_polarity_comment.mean()

        recipe_sentiment['mean_negativity_sentences'] = 100*comments_with_sentences_100[
                    (comments_with_sentences_100.sentiment_polarity_sentence < 0) 
                    & (comments_with_sentences_100.title == recipe_title)].sentiment_polarity_sentence.mean()
        
        recipe_sentiment['mean_negativity_comment'] = 100*comments_with_sentences_100[
                    (comments_with_sentences_100.sentiment_polarity_comment < 0) 
                    & (comments_with_sentences_100.title == recipe_title)].sentiment_polarity_comment.mean()
        
        recipe_sentiment['sentence_rank'] = (positive - negative)*(recipes[recipes.title==title].numberofcomments)
        
        recipe_sentiment['plot_name'] = recipe_title + '.jpg'
        
        
        recipe_ranks[i] = recipe_sentiment
        
        
# ranks = pd.DataFrame(recipe_ranks)

# %%
recipe_ranks[0] = recipe_sentiment

# %%
ranks = pd.DataFrame.from_dict(recipe_ranks, orient='index')
ranks
# Out:
#     mean_positivity_comment                                 numberofcomments  \
# 0                 32.005106    0    259
# Name: numberofcomments, dtype: int64
# 1                 34.126572    1    993
# Name: numberofcomments, dtype: int64
# 2                 25.562205     2    47
# Name: numberofcomments, dtype: int64
# 3                 33.022786    3    217
# Name: numberofcomments, dtype: int64
# 4                 36.836628    4    222
# Name: numberofcomments, dtype: int64
# 5                 26.269360    5    112
# Name: numberofcomments, dtype: int64
# 6                 36.754380     6    44
# Name: numberofcomments, dtype: int64
# 7                 31.445060    7    327
# Name: numberofcomments, dtype: int64
# 8                 33.038985     8    77
# Name: numberofcomments, dtype: int64
# 9                 31.731212    9    157
# Name: numberofcomments, dtype: int64
# 10                28.511970   10    474
# Name: numberofcomments, dtype: int64
# 11                32.358414   11    358
# Name: numberofcomments, dtype: int64
# 12                36.811215   12    842
# Name: numberofcomments, dtype: int64
# 13                36.217619   13    299
# Name: numberofcomments, dtype: int64
# 14                37.420777   14    254
# Name: numberofcomments, dtype: int64
# 15                30.392060   15    366
# Name: numberofcomments, dtype: int64
# 16                27.651966   16    131
# Name: numberofcomments, dtype: int64
# 17                32.181802   17    218
# Name: numberofcomments, dtype: int64
# 18                40.468838    18    31
# Name: numberofcomments, dtype: int64
# 19                30.872722   19    104
# Name: numberofcomments, dtype: int64
# 20                32.064294   20    848
# Name: numberofcomments, dtype: int64
# 21                29.818535   21    247
# Name: numberofcomments, dtype: int64
# 22                31.834990   22    406
# Name: numberofcomments, dtype: int64
# 23                38.844795   23    123
# Name: numberofcomments, dtype: int64
# 24                33.366053   24    607
# Name: numberofcomments, dtype: int64
# 25                26.164845    25    75
# Name: numberofcomments, dtype: int64
# 26                34.054262   26    168
# Name: numberofcomments, dtype: int64
# 27                32.274000    27    79
# Name: numberofcomments, dtype: int64
# 28                31.460697   28    583
# Name: numberofcomments, dtype: int64
# 29                29.827152    29    90
# Name: numberofcomments, dtype: int64
# ..                      ...                                              ...
# 70                29.858233   70    303
# Name: numberofcomments, dtype: int64
# 71                35.949390   71    480
# Name: numberofcomments, dtype: int64
# 72                28.559250   72    659
# Name: numberofcomments, dtype: int64
# 73                32.001407   73    614
# Name: numberofcomments, dtype: int64
# 74                33.703010  74    1237
# Name: numberofcomments, dtype: int64
# 75                28.702711   75    166
# Name: numberofcomments, dtype: int64
# 76                34.842937   76    265
# Name: numberofcomments, dtype: int64
# 77                30.213438    77    85
# Name: numberofcomments, dtype: int64
# 78                29.779785   78    204
# Name: numberofcomments, dtype: int64
# 79                32.661306    79    62
# Name: numberofcomments, dtype: int64
# 80                36.798854   80    201
# Name: numberofcomments, dtype: int64
# 81                32.894523   81    310
# Name: numberofcomments, dtype: int64
# 82                34.924970   82    508
# Name: numberofcomments, dtype: int64
# 83                37.854429   83    142
# Name: numberofcomments, dtype: int64
# 84                30.352794   84    215
# Name: numberofcomments, dtype: int64
# 85                32.642391    85    93
# Name: numberofcomments, dtype: int64
# 86                33.905460   86    270
# Name: numberofcomments, dtype: int64
# 87                31.086775   87    113
# Name: numberofcomments, dtype: int64
# 88                32.603053   88    168
# Name: numberofcomments, dtype: int64
# 89                41.098927   89    194
# Name: numberofcomments, dtype: int64
# 90                32.545310    90    60
# Name: numberofcomments, dtype: int64
# 91                27.103227   91    166
# Name: numberofcomments, dtype: int64
# 92                28.739290   92    185
# Name: numberofcomments, dtype: int64
# 93                34.000654   93    320
# Name: numberofcomments, dtype: int64
# 94                31.810037   94    448
# Name: numberofcomments, dtype: int64
# 95                29.872064   95    440
# Name: numberofcomments, dtype: int64
# 96                32.880370   96    357
# Name: numberofcomments, dtype: int64
# 97                35.815239   97    177
# Name: numberofcomments, dtype: int64
# 98                37.005889   98    196
# Name: numberofcomments, dtype: int64
# 99                31.187314    99    88
# Name: numberofcomments, dtype: int64
#
#     mean_negativity_sentences                                 recipe_ID  \
# 0                  -22.780852    0    R0
# Name: recipe_ID, dtype: object
# 1                  -22.228985    1    R1
# Name: recipe_ID, dtype: object
# 2                  -32.348039    2    R2
# Name: recipe_ID, dtype: object
# 3                  -29.804901    3    R3
# Name: recipe_ID, dtype: object
# 4                  -24.813667    4    R4
# Name: recipe_ID, dtype: object
# 5                  -21.741757    5    R5
# Name: recipe_ID, dtype: object
# 6                  -30.011111    6    R6
# Name: recipe_ID, dtype: object
# 7                  -24.226824    7    R7
# Name: recipe_ID, dtype: object
# 8                  -20.734196    8    R8
# Name: recipe_ID, dtype: object
# 9                  -22.127426    9    R9
# Name: recipe_ID, dtype: object
# 10                 -22.444715  10    R10
# Name: recipe_ID, dtype: object
# 11                 -19.364812  11    R11
# Name: recipe_ID, dtype: object
# 12                 -21.378842  12    R12
# Name: recipe_ID, dtype: object
# 13                 -19.016959  13    R13
# Name: recipe_ID, dtype: object
# 14                 -26.396134  14    R14
# Name: recipe_ID, dtype: object
# 15                 -22.295369  15    R15
# Name: recipe_ID, dtype: object
# 16                 -26.547622  16    R16
# Name: recipe_ID, dtype: object
# 17                 -20.274792  17    R17
# Name: recipe_ID, dtype: object
# 18                 -21.371528  18    R18
# Name: recipe_ID, dtype: object
# 19                 -24.176232  19    R19
# Name: recipe_ID, dtype: object
# 20                 -24.393882  20    R20
# Name: recipe_ID, dtype: object
# 21                 -25.865518  21    R21
# Name: recipe_ID, dtype: object
# 22                 -22.926149  22    R22
# Name: recipe_ID, dtype: object
# 23                 -21.275647  23    R23
# Name: recipe_ID, dtype: object
# 24                 -21.290417  24    R24
# Name: recipe_ID, dtype: object
# 25                 -18.047345  25    R25
# Name: recipe_ID, dtype: object
# 26                 -21.086512  26    R26
# Name: recipe_ID, dtype: object
# 27                 -23.415143  27    R27
# Name: recipe_ID, dtype: object
# 28                 -21.764068  28    R28
# Name: recipe_ID, dtype: object
# 29                 -27.517215  29    R29
# Name: recipe_ID, dtype: object
# ..                        ...                                       ...
# 70                 -17.636989  70    R70
# Name: recipe_ID, dtype: object
# 71                 -25.963396  71    R71
# Name: recipe_ID, dtype: object
# 72                 -21.582412  72    R72
# Name: recipe_ID, dtype: object
# 73                 -23.875979  73    R73
# Name: recipe_ID, dtype: object
# 74                 -22.410323  74    R74
# Name: recipe_ID, dtype: object
# 75                 -25.284886  75    R75
# Name: recipe_ID, dtype: object
# 76                 -28.107914  76    R76
# Name: recipe_ID, dtype: object
# 77                 -23.217943  77    R77
# Name: recipe_ID, dtype: object
# 78                 -19.328357  78    R78
# Name: recipe_ID, dtype: object
# 79                 -31.449588  79    R79
# Name: recipe_ID, dtype: object
# 80                 -25.521036  80    R80
# Name: recipe_ID, dtype: object
# 81                 -23.262037  81    R81
# Name: recipe_ID, dtype: object
# 82                 -25.817714  82    R82
# Name: recipe_ID, dtype: object
# 83                 -25.249666  83    R83
# Name: recipe_ID, dtype: object
# 84                 -20.871183  84    R84
# Name: recipe_ID, dtype: object
# 85                 -18.931246  85    R85
# Name: recipe_ID, dtype: object
# 86                 -25.348526  86    R86
# Name: recipe_ID, dtype: object
# 87                 -22.410694  87    R87
# Name: recipe_ID, dtype: object
# 88                 -24.664002  88    R88
# Name: recipe_ID, dtype: object
# 89                 -24.523020  89    R89
# Name: recipe_ID, dtype: object
# 90                 -22.991111  90    R90
# Name: recipe_ID, dtype: object
# 91                 -22.927609  91    R91
# Name: recipe_ID, dtype: object
# 92                 -21.734225  92    R92
# Name: recipe_ID, dtype: object
# 93                 -23.101919  93    R93
# Name: recipe_ID, dtype: object
# 94                 -22.778963  94    R94
# Name: recipe_ID, dtype: object
# 95                 -23.115193  95    R95
# Name: recipe_ID, dtype: object
# 96                 -28.261197  96    R96
# Name: recipe_ID, dtype: object
# 97                 -23.438511  97    R97
# Name: recipe_ID, dtype: object
# 98                 -27.863716  98    R98
# Name: recipe_ID, dtype: object
# 99                 -17.885640  99    R99
# Name: recipe_ID, dtype: object
#
#     mean_negativity_comment  \
# 0                -24.174082
# 1                -19.150751
# 2                 -6.250000
# 3                -16.031882
# 4                -13.790238
# 5                -16.357477
# 6                -20.698121
# 7                -14.561116
# 8                 -8.737875
# 9                -14.001807
# 10               -11.828914
# 11               -11.548006
# 12                -9.867544
# 13               -14.310966
# 14               -14.730176
# 15               -11.542025
# 16               -13.923525
# 17                -8.659030
# 18               -19.722222
# 19               -20.477761
# 20               -11.861575
# 21               -13.171170
# 22               -13.969322
# 23               -14.809028
# 24               -15.109616
# 25               -12.700700
# 26               -26.299867
# 27                -9.584686
# 28               -13.520987
# 29               -30.065461
# ..                      ...
# 70               -12.555892
# 71               -23.569643
# 72               -14.575307
# 73               -17.063537
# 74               -16.273677
# 75               -22.060066
# 76               -14.204840
# 77               -16.395289
# 78               -12.167791
# 79               -14.434316
# 80               -19.760036
# 81               -13.382780
# 82               -11.534624
# 83               -16.678792
# 84               -12.703275
# 85               -13.966544
# 86               -25.830060
# 87               -17.747691
# 88               -13.267196
# 89               -35.708023
# 90               -12.241521
# 91               -11.941779
# 92                -9.494216
# 93               -12.032429
# 94               -11.885689
# 95               -13.401295
# 96               -24.116354
# 97               -10.780389
# 98               -19.816663
# 99                -9.812305
#
#                                         sentence_rank  \
# 0   2    3506.751321
# Name: numberofcomments, dtype...
# 1   2    3506.751321
# Name: numberofcomments, dtype...
# 2   2    3506.751321
# Name: numberofcomments, dtype...
# 3   2    3506.751321
# Name: numberofcomments, dtype...
# 4   2    3506.751321
# Name: numberofcomments, dtype...
# 5   2    3506.751321
# Name: numberofcomments, dtype...
# 6   2    3506.751321
# Name: numberofcomments, dtype...
# 7   2    3506.751321
# Name: numberofcomments, dtype...
# 8   2    3506.751321
# Name: numberofcomments, dtype...
# 9   2    3506.751321
# Name: numberofcomments, dtype...
# 10  2    3506.751321
# Name: numberofcomments, dtype...
# 11  2    3506.751321
# Name: numberofcomments, dtype...
# 12  2    3506.751321
# Name: numberofcomments, dtype...
# 13  2    3506.751321
# Name: numberofcomments, dtype...
# 14  2    3506.751321
# Name: numberofcomments, dtype...
# 15  2    3506.751321
# Name: numberofcomments, dtype...
# 16  2    3506.751321
# Name: numberofcomments, dtype...
# 17  2    3506.751321
# Name: numberofcomments, dtype...
# 18  2    3506.751321
# Name: numberofcomments, dtype...
# 19  2    3506.751321
# Name: numberofcomments, dtype...
# 20  2    3506.751321
# Name: numberofcomments, dtype...
# 21  2    3506.751321
# Name: numberofcomments, dtype...
# 22  2    3506.751321
# Name: numberofcomments, dtype...
# 23  2    3506.751321
# Name: numberofcomments, dtype...
# 24  2    3506.751321
# Name: numberofcomments, dtype...
# 25  2    3506.751321
# Name: numberofcomments, dtype...
# 26  2    3506.751321
# Name: numberofcomments, dtype...
# 27  2    3506.751321
# Name: numberofcomments, dtype...
# 28  2    3506.751321
# Name: numberofcomments, dtype...
# 29  2    3506.751321
# Name: numberofcomments, dtype...
# ..                                                ...
# 70  2    3506.751321
# Name: numberofcomments, dtype...
# 71  2    3506.751321
# Name: numberofcomments, dtype...
# 72  2    3506.751321
# Name: numberofcomments, dtype...
# 73  2    3506.751321
# Name: numberofcomments, dtype...
# 74  2    3506.751321
# Name: numberofcomments, dtype...
# 75  2    3506.751321
# Name: numberofcomments, dtype...
# 76  2    3506.751321
# Name: numberofcomments, dtype...
# 77  2    3506.751321
# Name: numberofcomments, dtype...
# 78  2    3506.751321
# Name: numberofcomments, dtype...
# 79  2    3506.751321
# Name: numberofcomments, dtype...
# 80  2    3506.751321
# Name: numberofcomments, dtype...
# 81  2    3506.751321
# Name: numberofcomments, dtype...
# 82  2    3506.751321
# Name: numberofcomments, dtype...
# 83  2    3506.751321
# Name: numberofcomments, dtype...
# 84  2    3506.751321
# Name: numberofcomments, dtype...
# 85  2    3506.751321
# Name: numberofcomments, dtype...
# 86  2    3506.751321
# Name: numberofcomments, dtype...
# 87  2    3506.751321
# Name: numberofcomments, dtype...
# 88  2    3506.751321
# Name: numberofcomments, dtype...
# 89  2    3506.751321
# Name: numberofcomments, dtype...
# 90  2    3506.751321
# Name: numberofcomments, dtype...
# 91  2    3506.751321
# Name: numberofcomments, dtype...
# 92  2    3506.751321
# Name: numberofcomments, dtype...
# 93  2    3506.751321
# Name: numberofcomments, dtype...
# 94  2    3506.751321
# Name: numberofcomments, dtype...
# 95  2    3506.751321
# Name: numberofcomments, dtype...
# 96  2    3506.751321
# Name: numberofcomments, dtype...
# 97  2    3506.751321
# Name: numberofcomments, dtype...
# 98  2    3506.751321
# Name: numberofcomments, dtype...
# 99  2    3506.751321
# Name: numberofcomments, dtype...
#
#                                    recipe_title  \
# 0                   sweet potato buttermilk pie
# 1                           best cocoa brownies
# 2                                         sav’h
# 3                            classic cobb salad
# 4    cumin seed roasted cauliflower with yogurt
# 5                             chocolate pavlova
# 6            homemade merguez with herby yogurt
# 7                    fudgy chocolate sheet cake
# 8                    israeli salad + pita chips
# 9              failproof crepes + a crepe party
# 10                               zucchini bread
# 11             zucchini, tomato and rice gratin
# 12                      red wine chocolate cake
# 13  burst tomato galette with corn and zucchini
# 14                      zucchini bread pancakes
# 15               build your own smitten kitchen
# 16                            piri piri chicken
# 17                             confetti cookies
# 18                             freedom, ringing
# 19           plum squares with marzipan crumble
# 20           tomato sauce with onion and butter
# 21                        slow-roasted tomatoes
# 22                                broccoli slaw
# 23            white bean roasted red pepper dip
# 24                    perfect blueberry muffins
# 25                              how to julienne
# 26                         quick zucchini sauté
# 27     acorn squash with chile-lime vinaigrette
# 28            salted brown butter crispy treats
# 29                             cherry clafoutis
# ..                                          ...
# 70                      bourbon peach hand pies
# 71                    ratatouille’s ratatouille
# 72                          new york cheesecake
# 73                               homemade oreos
# 74                 chocolate peanut butter cake
# 75                                   oven fries
# 76                nectarine brown butter buckle
# 77           blueberry bread and butter pudding
# 78                          summer squash pizza
# 79                        peach melba popsicles
# 80                        strawberry shortcakes
# 81               sweet and smoky oven spareribs
# 82   how to poach an egg, smitten kitchen-style
# 83             roasted carrot and avocado salad
# 84                blackberry cheesecake galette
# 85       eggplant with yogurt and tomato relish
# 86        almond-crisped peaches + uk book tour
# 87                    potato pizza, even better
# 88                       key lime pie popsicles
# 89           tomato salad with crushed croutons
# 90                        apple cranberry crisp
# 91                           rugelach pinwheels
# 92                       nutmeg-maple cream pie
# 93                                    peach pie
# 94              my favorite buttermilk biscuits
# 95      project wedding cake: the cake is baked
# 96             scalloped tomatoes with croutons
# 97           blue and red berry ricotta galette
# 98                   raspberry limeade slushies
# 99                   ice cream sandwich cookies
#
#                                           plot_name  mean_positivity_sentences
# 0                   sweet potato buttermilk pie.jpg                  41.522664
# 1                           best cocoa brownies.jpg                  45.955384
# 2                                         sav’h.jpg                  42.263691
# 3                            classic cobb salad.jpg                  44.310971
# 4    cumin seed roasted cauliflower with yogurt.jpg                  47.630698
# 5                             chocolate pavlova.jpg                  39.174003
# 6            homemade merguez with herby yogurt.jpg                  47.783939
# 7                    fudgy chocolate sheet cake.jpg                  44.693298
# 8                    israeli salad + pita chips.jpg                  42.635496
# 9              failproof crepes + a crepe party.jpg                  42.309816
# 10                               zucchini bread.jpg                  40.325498
# 11             zucchini, tomato and rice gratin.jpg                  45.527744
# 12                      red wine chocolate cake.jpg                  47.723929
# 13  burst tomato galette with corn and zucchini.jpg                  48.034003
# 14                      zucchini bread pancakes.jpg                  47.969134
# 15               build your own smitten kitchen.jpg                  43.828878
# 16                            piri piri chicken.jpg                  43.382192
# 17                             confetti cookies.jpg                  45.832411
# 18                             freedom, ringing.jpg                  48.550908
# 19           plum squares with marzipan crumble.jpg                  41.664060
# 20           tomato sauce with onion and butter.jpg                  42.685017
# 21                        slow-roasted tomatoes.jpg                  43.102664
# 22                                broccoli slaw.jpg                  45.641429
# 23            white bean roasted red pepper dip.jpg                  48.262022
# 24                    perfect blueberry muffins.jpg                  45.396417
# 25                              how to julienne.jpg                  39.717468
# 26                         quick zucchini sauté.jpg                  43.966080
# 27     acorn squash with chile-lime vinaigrette.jpg                  46.359109
# 28            salted brown butter crispy treats.jpg                  43.281961
# 29                             cherry clafoutis.jpg                  44.040612
# ..                                              ...                        ...
# 70                      bourbon peach hand pies.jpg                  44.473431
# 71                    ratatouille’s ratatouille.jpg                  46.915121
# 72                          new york cheesecake.jpg                  40.443983
# 73                               homemade oreos.jpg                  44.835165
# 74                 chocolate peanut butter cake.jpg                  44.897468
# 75                                   oven fries.jpg                  40.653824
# 76                nectarine brown butter buckle.jpg                  47.072410
# 77           blueberry bread and butter pudding.jpg                  42.222593
# 78                          summer squash pizza.jpg                  43.397250
# 79                        peach melba popsicles.jpg                  42.543685
# 80                        strawberry shortcakes.jpg                  47.671443
# 81               sweet and smoky oven spareribs.jpg                  43.258498
# 82   how to poach an egg, smitten kitchen-style.jpg                  44.167423
# 83             roasted carrot and avocado salad.jpg                  50.128951
# 84                blackberry cheesecake galette.jpg                  43.883875
# 85       eggplant with yogurt and tomato relish.jpg                  45.566351
# 86        almond-crisped peaches + uk book tour.jpg                  46.984942
# 87                    potato pizza, even better.jpg                  43.991282
# 88                       key lime pie popsicles.jpg                  41.745339
# 89           tomato salad with crushed croutons.jpg                  51.788748
# 90                        apple cranberry crisp.jpg                  39.349084
# 91                           rugelach pinwheels.jpg                  40.427802
# 92                       nutmeg-maple cream pie.jpg                  40.490121
# 93                                    peach pie.jpg                  45.670616
# 94              my favorite buttermilk biscuits.jpg                  43.295724
# 95      project wedding cake: the cake is baked.jpg                  41.419218
# 96             scalloped tomatoes with croutons.jpg                  45.264630
# 97           blue and red berry ricotta galette.jpg                  48.667377
# 98                   raspberry limeade slushies.jpg                  46.179729
# 99                   ice cream sandwich cookies.jpg                  46.898543
#
# [100 rows x 9 columns]

# %%
recipes[recipes.title == recipe_title].author
# Out:
# 99    deb
# Name: author, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-234-46d1bf606fbf> in <module>()
# ----> 1 recipes[recipes.title == recipe_title].loc[:,0]
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     782     def _getitem_tuple(self, tup):
#     783         try:
# --> 784             return self._getitem_lowerdim(tup)
#     785         except IndexingError:
#     786             pass
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     906         for i, key in enumerate(tup):
#     907             if is_label_like(key) or isinstance(key, tuple):
# --> 908                 section = self._getitem_axis(key, axis=i)
#     909
#     910                 # we have yielded a scalar ?
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1391
#    1392             try:
# -> 1393                 key = self._convert_scalar_indexer(key, axis)
#    1394                 if key not in ax:
#    1395                     error()
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     185         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     186         # a scalar
# --> 187         return ax._convert_scalar_indexer(key, kind=self.name)
#     188
#     189     def _convert_slice_indexer(self, key, axis):
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    1010             elif kind in ['loc'] and is_integer(key):
#    1011                 if not self.holds_integer():
# -> 1012                     return self._invalid_indexer('label', key)
#    1013
#    1014         return key
#
# /Users/kateliea/anaconda/envs/py3/lib/python3.5/site-packages/pandas/indexes/base.py in _invalid_indexer(self, form, key)
#    1123                         "indexers [{key}] of {kind}".format(
#    1124                             form=form, klass=type(self), key=key,
# -> 1125                             kind=type(key)))
#    1126
#    1127     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
recipes.columns
# Out:
# Index(['article_id', 'author', 'author_url', 'directions', 'firstimageURL',
#        'ingredients', 'introductory_text', 'numberofcomments', 'published',
#        'recipe_notes', 'servings', 'time', 'title', 'updated', 'url',
#        'recipe_ID'],
#       dtype='object')
