# %%
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; float:center}</style>")
# Out:
# <style>.container { width:100% !important; float:center}</style>

# %%
from __future__ import division, print_function

import os
import glob
import math
import re
import pandas as pd
import numpy as np
# import scipy as sp
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
from time import sleep
import json
import re
import datetime
import time

import nltk
from nltk.corpus import stopwords, inaugural, brown
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk import Text

import heapq
import wordcloud as wc

import nltk.stem.porter as ptr

import collections
from itertools import groupby


# %matplotlib inline

sns.set_context('notebook')
sns.set_style('ticks')

# %%
similarity_corpus = Text(inaugural.words())
stops = set(stopwords.words('english'))
    # using a set will make it faster to run through...

punctuation = ['.',',',':','!',';','-','?','"',"'",'(',')','–']   
other = ['deb','hideb','don','didn','twaittry','doesn','thank','heydeb']
    
stops_punc = set(stopwords.words('english') + punctuation)

stops_all = set(stopwords.words('english') + punctuation + other)

# %% [markdown]
# import

# %%
comments = pd.read_csv('/Users/kateliea/Documents/Insight/project/webscrapers/comments_smittenkitchen_100_2.csv', index_col=0)
recipes = pd.read_csv('/Users/kateliea/Documents/Insight/project/webscrapers/recipes_smittenkitchen_100_2.csv', index_col=0)

# %% [markdown]
# sanity check

# %%
recipes.numberofcomments.sum(), len(comments)
# Out:
# (27776, 27776)

# %%
comments
# Out:
#        child_id children  commentID         comment_time  recipenumber  \
# 0             0       no          0  2009-11-17 11:44:00             0
# 1             0       no          1  2009-11-17 11:44:00             0
# 2             0       no          2  2009-11-17 11:44:00             0
# 3             0       no          3  2009-11-17 11:44:00             0
# 4             0       no          4  2009-11-17 11:44:00             0
# 5             0       no          5  2009-11-17 11:44:00             0
# 6             0       no          6  2009-11-17 11:44:00             0
# 7             0       no          7  2009-11-17 11:44:00             0
# 8             9      yes          8  2009-11-17 11:44:00             0
# 9             0       no          9  2009-11-17 11:44:00             0
# 10            0       no         10  2009-11-17 11:44:00             0
# 11            0       no         11  2009-11-17 11:44:00             0
# 12           13      yes         12  2009-11-17 11:44:00             0
# 13            0       no         13  2009-11-17 11:44:00             0
# 14            0       no         14  2009-11-17 11:44:00             0
# 15            0       no         15  2009-11-17 11:44:00             0
# 16            0       no         16  2009-11-17 11:44:00             0
# 17            0       no         17  2009-11-17 11:44:00             0
# 18            0       no         18  2009-11-17 11:44:00             0
# 19            0       no         19  2009-11-17 11:44:00             0
# 20            0       no         20  2009-11-17 11:44:00             0
# 21            0       no         21  2009-11-17 11:44:00             0
# 22            0       no         22  2009-11-17 11:44:00             0
# 23            0       no         23  2009-11-17 11:44:00             0
# 24            0       no         24  2009-11-17 11:44:00             0
# 25            0       no         25  2009-11-17 11:44:00             0
# 26            0       no         26  2009-11-17 11:44:00             0
# 27            0       no         27  2009-11-17 11:44:00             0
# 28           29      yes         28  2009-11-17 11:44:00             0
# 29            0       no         29  2009-11-17 11:44:00             0
# ...         ...      ...        ...                  ...           ...
# 27755  Hi deb.  I’m a regular follower of yours and h...
# 27756  LOVE the molasses!  I made them tiny.  So good...
# 27757  I made the chocolate chip, and mine, too, were...
# 27758  I made the chocolate chip recipe last night fo...
# 27759  I recently bought an ice cream maker and made ...
# 27760  Seems like you’ve been fighting ads lately, so...
# 27761  Aloha! I am having the same issue as other pos...
# 27762  can anyone share how many cookies the chocolat...
# 27763  Tried the Chocolate Chip cookies for the secon...
# 27764  Always let the dough sit in the fridge for at ...
# 27765  I just made the chocolate chip cookies and the...
# 27766  The “why aren’t my cookies flat?” query contin...
# 27767  Molasses again.  LOVE them.  We make them real...
# 27768  How many cookies does this recipe make? I have...
# 27769  These cookies are delightful to make and bake....
# 27770  I was just using your blog to make out my week...
# 27771  Hi – I am concerned about the order of ingredi...
# 27772  CC — It is not the usual way, but it works per...
# 27773  For the molasses cookies, does the dough freez...
# 27774                              Kelli — Yes, it does.
# 27775  And, almost 10 years later, I just made the mo...
#
#                                username  \
# 0      Tabitha (From Single to Married)
# 1                                  Cari
# 2            Jessica at How Sweet It Is
# 3                                LauraC
# 4            Christie @ Honoring Health
# 5                                Brenda
# 6                                  Dawn
# 7                               RachelM
# 8                                 jenni
# 9                                   deb
# 10                               Alyson
# 11                             Adrienne
# 12                                Carol
# 13                                  deb
# 14                    Beth @ 990 Square
# 15                             Jennette
# 16                Seth @ Boy Meets Food
# 17                         Southern Gal
# 18                    The Teacher Cooks
# 19                  The Gardener’s Eden
# 20                                Sarah
# 21                              Dorothy
# 22                                Susan
# 23                    The Purple Foodie
# 24                                Jilly
# 25                              Rebecca
# 26            Shauna from Piece of Cake
# 27                                annie
# 28                                Patty
# 29                                  deb
# ...                                 ...
# 27746                             lemon
# 27747                             Jodie
# 27748                              zack
# 27749              kouli kouli (Marine)
# 27750                              Erin
# 27751                      olivia wilde
# 27752                            Maremi
# 27753                               deb
# 27754                               Amy
# 27755                             Alice
# 27756                             Eliza
# 27757                              Anna
# 27758                            Janell
# 27759                             Buddy
# 27760                           Giovani
# 27761                         cheru1022
# 27762                               pws
# 27763                              Safa
# 27764                         Madrushka
# 27765                          Velocity
# 27766                             Julia
# 27767                             Eliza
# 27768                             Sarah
# 27769                           MamaKat
# 27770                       Kate Arnold
# 27771                                CC
# 27772                               deb
# 27773                             Kelli
# 27774                               deb
# 27775                               Fal
#
#                                                 usersite
# 0                     http://www.fromsingletomarried.com
# 1                                                   none
# 2                                http://howsweeteats.com
# 3                        http://JonAndLaura.blogspot.com
# 4                           http://www.honormyhealth.com
# 5                                                   none
# 6                                                   none
# 7                                                   none
# 8                                                   none
# 9                              http://smittenkitchen.com
# 10                     http://vivalafoodie.blogspot.com/
# 11                            http://www.hungrybruno.com
# 12                                 http://bit.ly/Ext2Rod
# 13                             http://smittenkitchen.com
# 14                              http://www.990square.com
# 15     http://snackreligious.blogspot.com/2009/11/gui...
# 16                           http://www.boymeetsfood.com
# 17                                                  none
# 18                        http://www.theteachercooks.com
# 19                       http://www.thegardenerseden.com
# 20                                http://www.fuzzynk.com
# 21                 http://belleofthekitchen.blogspot.com
# 22                                                  none
# 23                              http://purplefoodie.com/
# 24                                                  none
# 25                  http://www.thymeforwine.blogspot.com
# 26                   http://pieceofcakeblog.blogspot.com
# 27                                                  none
# 28                                 http://smittenkitchen
# 29                             http://smittenkitchen.com
# ...                                                  ...
# 27746                                               none
# 27747                        http://whatsthescooppdx.com
# 27748                                               none
# 27749                 http://marine-vallet.blogspot.com/
# 27750                                               none
# 27751                     http://www.theoliviawilde.info
# 27752                                               none
# 27753                          http://smittenkitchen.com
# 27754                                               none
# 27755                                               none
# 27756                                               none
# 27757                                               none
# 27758                                               none
# 27759                                               none
# 27760                    http://www.gramfeed.com/gioioio
# 27761                                               none
# 27762                                               none
# 27763                                               none
# 27764                                               none
# 27765                                               none
# 27766                                               none
# 27767                                               none
# 27768                                               none
# 27769                                               none
# 27770                                               none
# 27771                                               none
# 27772                          http://smittenkitchen.com
# 27773                                               none
# 27774                          http://smittenkitchen.com
# 27775                                               none
#
# [27776 rows x 10 columns]

# %% [markdown]
# for a given recipe, dump all the comment text into one giant list

# %%
comments.columns
# Out:
# Index(['child_id', 'children', 'commentID', 'comment_time', 'recipenumber',
#        'title', 'url', 'usercomment', 'username', 'usersite'],
#       dtype='object')

# %% [markdown]
# case with just the first recipe in the corpus

# %%
commentslist = []
for comment in comments[comments.title == recipes.title.iloc[0]].usercomment:
#     commentslist += [comment.strip('\n').lower()]
    cleaned = re.sub(r"\n", " ", comment.lower())  
    commentslist += [re.sub(r"'", "", cleaned)]
    
#     commentslist += [re.sub(r"\r\n", "  ", comment.lower())]
    
commentslist_joined = ' '.join(commentslist)

# %%
tokens = word_tokenize(commentslist_joined)
bigrams = ngrams(tokens,2)
trigrams = ngrams(tokens,3)
len(tokens)
# Out:
# 11467

# %% [markdown]
# remove stopwords

# %%
unstopped = [word for word in tokens if word not in stops]
unstopped_nopunctuation = [word for word in tokens if word not in stops_all]
len(unstopped), len(unstopped_nopunctuation)
# Out:
# (6893, 5396)

# %% [markdown]
# stem

# %%
stemmer = ptr.PorterStemmer()
stems = [stemmer.stem(word) for word in unstopped_nopunctuation]

# %% [markdown]
# some word visualizations

# %%
# take relative word frequencies into account, lower max_font_size
wordcloud = wc.WordCloud(max_font_size=40, relative_scaling=.5).generate(' '.join(unstopped))
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# take relative word frequencies into account, lower max_font_size
wordcloud = wc.WordCloud(max_font_size=30, relative_scaling=.5).generate(' '.join(unstopped_nopunctuation))
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.show()

# %%
wordcloud = wc.WordCloud(max_font_size=30, relative_scaling=.5).generate(' '.join(unstopped))
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud)
sns.despine()
plt.show()

# %%
commentslist_joined.similar('try')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-c580c9fe211d> in <module>()
# ----> 1 commentslist_joined.similar('try')
#
# AttributeError: 'str' object has no attribute 'similar'
