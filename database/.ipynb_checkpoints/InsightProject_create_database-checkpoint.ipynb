# %%
from __future__ import print_function, division
import sqlalchemy as sql
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd

sql.MetaData()

# %%
dbname = 'insight_project'
username = 'kateliea'

# %%
engine = create_engine('postgres://%s@localhost/%s' % (username, dbname))
print(engine.url)
# Out:
# postgres://kateliea@localhost/insight_project

# %%
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
train = pd.read_csv('/Users/kateliea/Documents/Insight/project/algorithm/training_data.csv')

# %%
train.to_sql('training_data_table',engine,if_exists='replace')

# %%
engine.table_names()
# Out:
# [u'sentences_table',
#  u'recipes_table',
#  u'comments_table',
#  u'training_data_table']

# %%
# connect:
con = None
con = psycopg2.connect(database = dbname, user = username)

# %%
# query:
sql_query = """
SELECT * FROM recipes_table;
"""
data = pd.read_sql_query(sql_query,con)

data.head()
# Out:
#    index  article_id author                                author_url  \
# 0      0  post-29361    deb  https://smittenkitchen.com/author/debsk/
# 1      1  post-29320    deb  https://smittenkitchen.com/author/debsk/
# 2      2   post-5183    deb  https://smittenkitchen.com/author/debsk/
# 3      3   post-5631    deb  https://smittenkitchen.com/author/debsk/
# 4      4    post-200    deb  https://smittenkitchen.com/author/debsk/
#
#                                           directions  \
# 0                                               None
# 1                                               None
# 2  Whipped egg whites give this pie a frothy text...
# 3                                               None
# 4  Every time, and really, it’s never often enoug...
#
#                                        firstimageURL  \
# 0  https://smittenkitchendotcom.files.wordpress.c...
# 1  https://smittenkitchendotcom.files.wordpress.c...
# 2  https://smittenkitchendotcom.files.wordpress.c...
# ...

# %%
query = """
      SELECT title, url FROM recipes_table; 
      """
query_results = pd.read_sql_query(query,con)
recipes = []
for i in range(0,query_results.shape[0]):
    recipes.append(dict(index=i, recipe_title=query_results.iloc[i]['title'], url=query_results.iloc[i]['url']))

# %%
recipes
# Out:
# [{'recipe_title': 'magic apple plum\xc2\xa0cobbler',
#   'url': 'https://smittenkitchen.com/2016/09/magic-apple-plum-cobbler/'},
#  {'recipe_title': 'homemade merguez with herby\xc2\xa0yogurt',
#   'url': 'https://smittenkitchen.com/2016/09/homemade-merguez-with-herby-yogurt/'},
#  {'recipe_title': 'sweet potato buttermilk\xc2\xa0pie',
#   'url': 'https://smittenkitchen.com/2009/11/sweet-potato-buttermilk-pie/'},
#  {'recipe_title': 'best cocoa brownies',
#   'url': 'https://smittenkitchen.com/2010/01/best-cocoa-brownies/'},
#  {'recipe_title': 'sav\xe2\x80\x99h',
#   'url': 'https://smittenkitchen.com/2007/03/savh/'},
#  {'recipe_title': 'classic cobb salad',
#   'url': 'https://smittenkitchen.com/2010/04/classic-cobb-salad/'},
#  {'recipe_title': 'cumin seed roasted cauliflower with\xc2\xa0yogurt',
#   'url': 'https://smittenkitchen.com/2011/10/cumin-seed-roasted-cauliflower-with-yogurt/'},
#  {'recipe_title': 'chocolate pavlova',
# ...

# %%
recipes = sorted(recipes)

# %%
recipes
# Out:
# [{'recipe_title': '10 paths to painless\xc2\xa0pizza-making',
#   'url': 'https://smittenkitchen.com/2008/06/10-paths-to-painless-pizza-making/'},
#  {'recipe_title': '17 flourless dessert\xc2\xa0ideas',
#   'url': 'https://smittenkitchen.com/2008/04/17-passover-dessert-ideas/'},
#  {'recipe_title': 'a slice-and-bake cookie\xc2\xa0palette',
#   'url': 'https://smittenkitchen.com/2007/12/a-slice-and-bake-cookie-palette/'},
#  {'recipe_title': 'a tatin, auditioned',
#   'url': 'https://smittenkitchen.com/2007/01/a-tatin-auditioned/'},
#  {'recipe_title': 'acorn squash quesadillas + tomatillo\xc2\xa0salsa',
#   'url': 'https://smittenkitchen.com/2008/10/acorn-squash-quesadillas-tomatillo-salsa/'},
#  {'recipe_title': 'acorn squash with chile-lime\xc2\xa0vinaigrette',
#   'url': 'https://smittenkitchen.com/2006/10/unflinchingly-good-things/'},
#  {'recipe_title': 'alex\xe2\x80\x99s chicken and mushroom\xc2\xa0marsala',
# ...
